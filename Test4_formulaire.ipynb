# %%
"""
Test4 : le tableau widget fonctionne.. maintenant.. il faut qu'il soit vide au début..
puis qu'il se remplisse avec les données..

Il faut un code en python qui écrive le contenu de la chaîne de charactères value du widget html_Tab :
* donc il y a des bloc de chaîne toujours présents qui entrent avec une séquence particulière :
1. <table style=' border-color:black;border-style:solid;border-width:1px;font-size:14px; !important;'>
2. <tr>
4. </tr>
6. </table>

* il y a des chaînons variables ( en nombre variable selon le nombre de colonne.. et/ou de lignes ! ) 
qui eux aussi s'insèrent à des endroits de la séquence particulier..

3. VariatCol (en tête --> 1 seule ligne) :
<th style='background-color: MediumTurquoise;padding: 2% 18% % 2%; border: 1px  black solid !important;'> *head_Col* </th>
5. VariatLign 
    <tr>
    ... et VariatCol :
            <th  style='border: 1px  black solid !important;'> *Données_Lign_Col* </th>
    </tr>

"""

# %%
Ligns, Cols = 6, 6
Chaine = "<table style=' border-color:black;border-style:solid;border-width:1px;font-size:14px; !important;'><tr>"
for Col in range(1, Cols+1):
    Chaine += "<th style='background-color: MediumTurquoise;padding: 2% 2% % 2%; border: 1px  black solid !important;'> *head_"+str(Col)+"* </th>"
Chaine += "</tr>"
for Lign in range(1, Ligns+1):
    Chaine += "<tr>"
    for Col in range(1, Cols+1):
        Chaine += "<th  style='border: 1px  black solid !important;'> *Données_"+str(Lign)+"_"+str(Col)+"* </th>"
    Chaine += "</tr>"
Chaine += "</table>"
print(Chaine)
# Out:
# <table style=' border-color:black;border-style:solid;border-width:1px;font-size:14px; !important;'><tr><th style='background-color: MediumTurquoise;padding: 2% 2% % 2%; border: 1px  black solid !important;'> *head_1* </th><th style='background-color: MediumTurquoise;padding: 2% 2% % 2%; border: 1px  black solid !important;'> *head_2* </th><th style='background-color: MediumTurquoise;padding: 2% 2% % 2%; border: 1px  black solid !important;'> *head_3* </th><th style='background-color: MediumTurquoise;padding: 2% 2% % 2%; border: 1px  black solid !important;'> *head_4* </th><th style='background-color: MediumTurquoise;padding: 2% 2% % 2%; border: 1px  black solid !important;'> *head_5* </th><th style='background-color: MediumTurquoise;padding: 2% 2% % 2%; border: 1px  black solid !important;'> *head_6* </th></tr><tr><th  style='border: 1px  black solid !important;'> *Données_1_1* </th><th  style='border: 1px  black solid !important;'> *Données_1_2* </th><th  style='border: 1px  black s
# ...

# %% [markdown]
# <table style=' border-color:black;border-style:solid;border-width:1px;font-size:14px; !important;'><tr><th style='background-color: MediumTurquoise;padding: 2% 2% % 2%; border: 1px  black solid !important;'> *head_1* </th><th style='background-color: MediumTurquoise;padding: 2% 2% % 2%; border: 1px  black solid !important;'> *head_2* </th><th style='background-color: MediumTurquoise;padding: 2% 2% % 2%; border: 1px  black solid !important;'> *head_3* </th><th style='background-color: MediumTurquoise;padding: 2% 2% % 2%; border: 1px  black solid !important;'> *head_4* </th><th style='background-color: MediumTurquoise;padding: 2% 2% % 2%; border: 1px  black solid !important;'> *head_5* </th><th style='background-color: MediumTurquoise;padding: 2% 2% % 2%; border: 1px  black solid !important;'> *head_6* </th></tr><tr><th  style='border: 1px  black solid !important;'> *Données_1_1* </th><th  style='border: 1px  black solid !important;'> *Données_1_2* </th><th  style='border: 1px  black solid !important;'> *Données_1_3* </th><th  style='border: 1px  black solid !important;'> *Données_1_4* </th><th  style='border: 1px  black solid !important;'> *Données_1_5* </th><th  style='border: 1px  black solid !important;'> *Données_1_6* </th></tr><tr><th  style='border: 1px  black solid !important;'> *Données_2_1* </th><th  style='border: 1px  black solid !important;'> *Données_2_2* </th><th  style='border: 1px  black solid !important;'> *Données_2_3* </th><th  style='border: 1px  black solid !important;'> *Données_2_4* </th><th  style='border: 1px  black solid !important;'> *Données_2_5* </th><th  style='border: 1px  black solid !important;'> *Données_2_6* </th></tr><tr><th  style='border: 1px  black solid !important;'> *Données_3_1* </th><th  style='border: 1px  black solid !important;'> *Données_3_2* </th><th  style='border: 1px  black solid !important;'> *Données_3_3* </th><th  style='border: 1px  black solid !important;'> *Données_3_4* </th><th  style='border: 1px  black solid !important;'> *Données_3_5* </th><th  style='border: 1px  black solid !important;'> *Données_3_6* </th></tr><tr><th  style='border: 1px  black solid !important;'> *Données_4_1* </th><th  style='border: 1px  black solid !important;'> *Données_4_2* </th><th  style='border: 1px  black solid !important;'> *Données_4_3* </th><th  style='border: 1px  black solid !important;'> *Données_4_4* </th><th  style='border: 1px  black solid !important;'> *Données_4_5* </th><th  style='border: 1px  black solid !important;'> *Données_4_6* </th></tr><tr><th  style='border: 1px  black solid !important;'> *Données_5_1* </th><th  style='border: 1px  black solid !important;'> *Données_5_2* </th><th  style='border: 1px  black solid !important;'> *Données_5_3* </th><th  style='border: 1px  black solid !important;'> *Données_5_4* </th><th  style='border: 1px  black solid !important;'> *Données_5_5* </th><th  style='border: 1px  black solid !important;'> *Données_5_6* </th></tr><tr><th  style='border: 1px  black solid !important;'> *Données_6_1* </th><th  style='border: 1px  black solid !important;'> *Données_6_2* </th><th  style='border: 1px  black solid !important;'> *Données_6_3* </th><th  style='border: 1px  black solid !important;'> *Données_6_4* </th><th  style='border: 1px  black solid !important;'> *Données_6_5* </th><th  style='border: 1px  black solid !important;'> *Données_6_6* </th></tr></table>

# %% [markdown]
# https://www.tutorialspoint.com/creating-a-sqlite-database-from-csv-with-python

# %%
import os
import sqlite3
import pandas as pd
import csv
from ipywidgets import Widget
import ipywidgets as widgets
Lieu = os.getcwd()

# %%
Tab =widgets.HTML(
    # value="Hello <b>World</b>",
    
    value = """<table style=' border-color:black;border-style:solid;border-width:1px;font-size:14px; !important;'><tr><th style='background-color: MediumTurquoise;padding: 2% 18% % 2%; border: 1px  black solid !important;'> *1* </th><th style='background-color: MediumTurquoise; padding: 2% 18% 2% 2%; border: 1px  black solid !important;'> *2* </th><th style='background-color: MediumTurquoise; padding: 2% 18% 2% 2%; border: 1px  black solid !important;'> *3* </th></tr>
    
<tr><th  style='border: 1px  black solid !important;'> *1* </th><th style='border: 1px  black solid !important;'>*2* </th><th style='border: 1px  black solid !important;'>*3* </th></tr>  
    
</table>
    
    """,
    
    
    placeholder='Some HTML',
    description='Some HTML',
)
Tab

# %%
# drop table if exists table_name

# %%
#############################################################
""" Retourne Le nom de la BDD et la liste des tables """
def Recup_Nom_BDD_List_Tabl(Chemin):
    BDD_Nom = os.path.basename(Chemin)
    List_Tabl=[os.path.join(f) for f in os.listdir(Chemin) if f.endswith(".csv")]
    return BDD_Nom, List_Tabl
#############################################################
def Creer_BDD(_):
    global cur

    ################################
    fichier = open("Tab1.csv",encoding="utf-8-sig")
    Etudiants = list(csv.DictReader(fichier, delimiter=";"))
    ##
    # print("Cette table contient : ",len(Etudiants), "Etudiants.")
    ##
    # if len(Etudiants) != 0:
        # print("\n",Etudiants[0])
    List_cle = list(Etudiants[0].keys())
    # print(List_cle)
    Nb_cle = len(List_cle)
    # print("Cette table contient ",Nb_cle," clés.")
    ###################################
    # CREATE TABLE IF NOT EXISTS
    request = "CREATE TABLE IF NOT EXISTS " + str(List_Tabl[0][:-4]) + " ("
    for colonne in range(Nb_cle):
        request = request + str(List_cle[colonne]) + " " + str(Etudiants[0][List_cle[colonne]]) + ", "
    request = request[:-2] + str(" )")
    # print(request)
    cur.execute(request)

#############################################################

# %%
####  Connexion
Lieu = os.getcwd()
BDD_Nom, List_Tabl = Recup_Nom_BDD_List_Tabl(Lieu)
# print("Liste des tables contenues dans la BDD nommée '",BDD_Nom,"' :",List_Tabl)
######################
# creating a connection to the database
BDD_Nom_fichier = BDD_Nom + ".db"
conn = sqlite3.connect(BDD_Nom_fichier)
# creating a cursor object
cur = conn.cursor()

# %%
# # creating a connection to the database
# BDD_Nom_fichier = BDD_Nom + ".db"
# conn = sqlite3.connect(BDD_Nom_fichier)

# %%
# # creating a cursor object
# cur = conn.cursor()

# %%
# fichier = open("Tab1.csv",encoding="utf-8-sig")
# Etudiants = list(csv.DictReader(fichier, delimiter=";"))
#
# print("Cette table contient : ",len(Etudiants), "Etudiants.")
#
# if len(Etudiants) != 0:
    # print("\n",Etudiants[0])
# List_cle = list(Etudiants[0].keys())
# print(List_cle)
# Nb_cle = len(List_cle)
# print("Cette table contient ",Nb_cle," clés.")

# %%
# CREATE TABLE IF NOT EXISTS
# request = "CREATE TABLE IF NOT EXISTS " + str(List_Tabl[0][:-4]) + " ("
# for colonne in range(Nb_cle):
    # request = request + str(List_cle[colonne]) + " " + str(Etudiants[0][List_cle[colonne]]) + ", "
# request = request[:-2] + str(" )")
# print(request)
# cur.execute(request)

# %%
Donnees = {}
Donnees_texte = ""
Donnees_label = widgets.Label(value=Donnees_texte)
display(Donnees_label)

# %%
tableau = "weppa"
tableau_label = widgets.Label(value=tableau)

# %%
Erreur_validation = "Erreurs : 0 ."
Erreur_validation_label = widgets.Label(value=Erreur_validation)

# %%
def Chang_Nom(change):
    global Donnees
    Nom = change['new']
    Donnees['Nom'] = Nom

# %%
def Chang_Prenom(change):
    global Donnees
    Prenom = change['new']
    Donnees['Prénom'] = Prenom

# %%
def Chang_Age(change):
    global Donnees
    Age = change['new']
    Donnees['Age'] = Age

# %%
def Validation(_):
    global Donnees
    List_cle_Donnees = list(Donnees.keys())
    Taille = len(List_cle_Donnees)
    Donnees_label.value = str(Donnees)
    display(Donnees_label)

    requette = "INSERT INTO " + str(List_Tabl[0][:-4]) + " " # + " ("
    
    # for colonne in List_cle_Donnees:
    #     requette = requette + str(colonne) + ","
    # requette = requette[:-1]
    # requette = requette + ") "
    
    requette = requette + "values ("
    List_valeur_Donnees = list(Donnees.values())
    for donn in List_valeur_Donnees:
        if type(donn) == str:
            requette = requette + "'" +str(donn) + "'" + ","
        else:
            requette = requette  +str(donn) + ","
    requette = requette[:-1]
    requette = requette + ")"       
    print(requette)
    try:
        cur.execute(requette)
        conn.commit()
#    except sqlite3.Error as e:
#        logger.error("Sqlite3.Error: " + str(e))
    except Exception as e:
        result = e
        # return result
        Erreur_validation_label.value=str(e)

# %%
def Visualise(_):
    global conn
    tableau = ""
    request = "SELECT * FROM " + str(List_Tabl[0][:-4])
    cur.execute(request)
    rows = cur.fetchall()
    for row in rows:
        tableau += str(row) + " \n"
    tableau_label.value = tableau
    ##
    df = pd.read_sql_query(request, conn)
    print(df.head())
    ##
    display(tableau_label)
    
# df = pd.read_sql_query("SELECT * from surveys", con)

# Verify that result of SQL query is stored in the dataframe
# print(df.head())

# con.close()

# %%
def Sortir(_):
    global conn
    conn.close()
    Widget.close_all()

# %%
Nom_Drop = widgets.Dropdown(
    options=['#','Fialaire', 'Dupont', 'Cruise'],
    value='#',
    description='Nom:',
    disabled=False,
)
Nom_Drop.observe(Chang_Nom, names='value')
Nom_Drop

# %%
Prenom_Drop = widgets.Dropdown(
    options=['#','David', 'Jonh', 'Tom'],
    value='#',
    description='Prénom:',
    disabled=False,
)
Prenom_Drop.observe(Chang_Prenom, names='value')
Prenom_Drop

# %%
Age_Drop = widgets.Dropdown(
    options=['#','19', '20', '21'],
    value='#',
    description='Age:',
    disabled=False,
)
Age_Drop.observe(Chang_Age, names='value')
Age_Drop

# %%
bouton_Valid = widgets.Button(
    description='Validation',
    disabled=False,
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Validation ',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)
bouton_Valid.on_click(Validation)
bouton_Valid

# %%
Erreur_validation_label

# %%
bouton_Cree_Bdd = widgets.Button(
    description='Creation',
    disabled=False,
    button_style='info', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Creation ',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)
bouton_Cree_Bdd.on_click(Creer_BDD)
bouton_Cree_Bdd

# %%
bouton_Sortir = widgets.Button(
    description='Sortir',
    disabled=False,
    button_style='warning', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Sortir ',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)
bouton_Sortir.on_click(Sortir)
bouton_Sortir

# %%
bouton_Visualise = widgets.Button(
    description='Visualiser',
    disabled=False,
    button_style='info', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Visualiser ',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)
bouton_Visualise.on_click(Visualise)
bouton_Visualise

# %%
tableau_label

# %%
# cur.execute("INSERT INTO livre VALUES ('Les Aventures de Huckleberry Finn', 'Flammarion', '2023', '978-2081509511');")

# %%
# cur.execute("INSERT INTO livre VALUES ('Fondation et Empire', 'Editions Denoël', '1999', '978-2207249123');")

# %%
# inserting data into the table
# for row in data:
#    cur.execute("INSERT INTO table_name (column1_name, column2_name, ...) values (?, ?, ...)", row)
# conn.commit()

# %%
# committing changes
# conn.commit()

# %%
# closing the connection
# conn.close()
